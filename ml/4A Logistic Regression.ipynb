# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Z:\ML\insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color='m')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df[['age']],df.bought_insurance,train_size=0.8)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
x_test
# Out:
#     age
# 10   18
# 2    47
# 8    62
# 14   49
# 11   28
# 0    22

# %%
y_predicted=model.predict(x_test)

# %%
model.predict_proba(x_test)
# Out:
# array([[0.93953648, 0.06046352],
#        [0.16497269, 0.83502731],
#        [0.02024372, 0.97975628],
#        [0.12755843, 0.87244157],
#        [0.77524416, 0.22475584],
#        [0.89485047, 0.10514953]])

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
y_predicted
# Out:
# array([0, 1, 1, 1, 0, 0], dtype=int64)

# %%
model.coef_
# Out:
# array([[0.15051831]])

# %%
model.intercept_
# Out:
# array([-5.45267598])
